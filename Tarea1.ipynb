# %%
from gurobipy import *

# Importar librerias

import pandas as pd
import time
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargar base de datos

# %%
pilotos = pd.read_csv('basepilotos.txt', sep = '\t', index_col = 0) 
pilotos.head()
# Out:
#           u1  u2  u3  u4  u5  u6  u7  u8  tipoA  tipoB
# idPiloto
# 1         20   9  12   3  15  16  12  14      0      1
# 2          1  10   4  22  21   6  22  14      1      0
# 3         15  13  12  13  15   9  10  13      1      1
# 4          7   2  17  14   9  19  15  19      1      1
# 5          5  20  16  21   2  29   8   0      1      0

# %%
vuelos = pd.read_csv('basevuelos.txt', sep = '\t', index_col=0)
vuelos.head()
# Out:
#              destino  tiempoVuelo  lunes  martes  miercoles  jueves  viernes  \
# idVuelo
# 1              Arica            4      1       1          1       1        3
# 2            Iquique            3      3       1          1       2        3
# 3        Antofagasta            2      2       2          2       2        3
# 4           LaSerena            1      2       1          1       1        3
# 5         Concepcion            1      1       1          1       1        2
#
#          sabado  domingo  tipoA  tipoB
# idVuelo
# 1             3        2      1      0
# 2             3        3      1      0
# 3             3        2      1      0
# 4             3        2      1      0
# 5             2        2      0      1

# %% [markdown]
# ### Crear modelo

# %%
modeloA = Model("ModeloA")

# %% [markdown]
# ### Cargar conjuntos y parametros

# %%
# Cargar Conjuntos

P = list(pilotos.index)
V = list(vuelos.index)
D = list([1,2,3,4,5,6,7])
I = list(["TipoA" , "TipoB"])

# %%
# Parámetros
u = pilotos.iloc[:,0:8]
b = pilotos.iloc[:,8:10]
t = vuelos['tiempoVuelo']
a = vuelos.iloc[:, 9:11]
n = vuelos.iloc[:,2:9]

# %% [markdown]
# ### Variables de Decisión

# %%
x = dict()
for pilotos in tqdm(P):
    for vuelos in tqdm(V):
        for dias in tqdm(D):
            x[pilotos, vuelos, dias]=modeloA.addVar(vtype='B')
# Out:
# ...
#   0%|                                                                                            | 0/8 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 92.91it/s]
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
# ...
#  38%|███████████████████████████████▌                                                    | 3/8 [00:00<00:00, 28.14it/s]
#
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
#
# ...
